# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached langchain_openai-0.1.16-py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached langchain_experimental-0.0.62-py3-none-any.whl.metadata (1.5 kB)
# ...
#   Using cached langchainhub-0.1.20-py3-none-any.whl.metadata (659 bytes)
# ...
#   Using cached pinecone_client-4.1.2-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached PyMuPDF-1.24.7.tar.gz (31.5 MB)
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   Preparing metadata (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [143 lines of output]
#   pymupdf_9d9302be643942f290deb730592a252c\setup.py: ### Starting.
#   pymupdf_9d9302be643942f290deb730592a252c\setup.py: __name__: 'setup'
# ...
